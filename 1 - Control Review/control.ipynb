# %% [markdown]
# # if-elif-else

# %%
def comparison_demo(num1, num2):
    """
    :param num1: number
    :param num2: number
    :return: Returns 1 if num1 is larger, 2 if num2 is larger, or 0 if neither is larger
    """
    if num1 > num2:
        print(num1, 'is greater than', num2)
        return 1
    elif num1 == num2:
        print(num1, 'and', num2, 'are equal')
        return 0
    else:
        print(num1, 'is less than', num2)
        return 2

# %%
comparison_demo(3, 4)

# %%
comparison_demo(3, 3)

# %% [markdown]
# # Practice
#
# Write a function that takes an integer as input.
# - Return the integer 3 if the input is divisible by 3 but not 5
# - Return the integer 5 if the input is divisible by 5 but not 3
# - Return the integer 15 if the input is divisible by both 3 and 5

# %%
def three_five_divides(num):
    if (num % 3 == 0) and (num % 5 != 0):
        return 3
    elif (num % 3 != 0) and (num % 5 == 0):
        return 5
    elif (num % 3 == 0) and (num % 5 == 0):
        return 15
    else:
        return 0

# %%
three_five_divides(15)

# %% [markdown]
# # while

# %%
def while_demo(input_int):
    """
    :param num1: number
    :return: print the first multiple of 10 that is greater than or equal to input_int
    """
    multiple = input_int
    while multiple % 10 != 0:
        print('multiple is currently:', multiple)
        multiple = multiple + 1

    return multiple

# %%
result = while_demo(50)
print(result)

# %%
result = while_demo(11)
print(result)

# %% [markdown]
# # Practice
#
# Write a function that takes an integer as input. Use a while loop to print the square of every even number strictly less than the input.

# %% [markdown]
# # for

# %%
def for_demo(input_int):
    """
    :param input_int: integer
    :return: sum of all integers from 1 to input_int, inclusive
    """
    the_sum = 0
    for current_int in range(1,input_int + 1):
        print('current_int has the value', current_int)
        the_sum = the_sum + current_int
        print(the_sum)

    return the_sum

# %%
result = for_demo(5)
print(result)

# %% [markdown]
# # Practice
#
# Write a function that takes an integer as input. Use a for loop to print the square of every number strictly less than the input.

# %% [markdown]
# # More examples

# %%
def is_prime(input_int):
    """
    :param input_int: integer
    :return: True if test_int is prime. False, otherwise.
    """
    for test_divisor in range(2, input_int):
        print('currently testing divisibility by:', test_divisor)
        if input_int % test_divisor == 0:
            return False

    # If you reach this line, then input_int is not divisible by anything in the
    # search range.
    return True

# %%
result = is_prime(10)
print(result)

# %%
result = is_prime(35)
print(result)

# %%
# You can create compound conditional statements using 'and' and 'or'
def either_prime(int1, int2):
    """
    :param int1: integer
    :param int2: integer
    :return: True if at least one of int1 or int2 is prime. False, otherwise.
    """
    if is_prime(int1) or is_prime(int2):
        return True
    
    return False

# %%
either_prime(3, 5)

# %%
either_prime(9, 35)

# %%
# Looping over strings uses the same syntax and proceeds one character at a time
test_string = 'hello'
for letter in test_string:
    print(letter)
